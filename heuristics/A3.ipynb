# %% [markdown]
# ## Inputs

# %% [markdown]
# 1. restaurant dimensions
# 1. number of timeslots?
# 1. marginal revenue function
# 1. cost of goodwill
# 1. randomly generated data - boolean
# 1. maximum table size
# 1. objective? - enum

# %% [markdown]
# ## Construction Heuristic

# %% [markdown]
# ### Algorithm
#
# 1. sort parties in order of descending size
# 1. add parties to the timeslot k until the restaurant capacity is full or no more tables can be added

# %% [markdown]
# ### Step 1: Parse input parameters

# %%
import json
import random

w = l = customer_goodwill = REVENUE_GOAL = num_timeslots = randomly_generated_data = 0
marginal_revenue = {}

# set of timeslots - static
K = 7

with open('../data.json') as f:
    data = json.load(f)
    w = data['restaurant_width']
    l = data['restaurant_length']
    customer_goodwill = data['customer_goodwill']
    REVENUE_GOAL = data['revenue_goal']
    randomly_generated_data = data['randomly_generated_data']
    max_party_size = data['max_party_size']
    for i in data['marginal_revenue']:
        marginal_revenue[int(i)] = data['marginal_revenue'][i]
        
# Restaurant squared area
MAX_SIZE = l * w

# %% [markdown]
# ### Step 2: Randomly generate data

# %%
# set of parties at each timeslot
# since there are 7 timeslots and since this data is randomly generated, 
# the set of parties during timelsot k will be I[k].
# Prior to having randomly generated demand we had set I = 40 (40 parties) for each timeslot
if randomly_generated_data == True:
    I = [
        random.randint(10,15), 
        random.randint(17,24),
        random.randint(17,24),
        random.randint(10,15),
        random.randint(25,40),
        random.randint(25,40),
        random.randint(10,15),
    ]

else:
    print("Please allow data to be randomly generated to ensure accuracy and reliability of results")


#initializing the party 
party_size = {}
for k in range(K):
    for i in range(I[k]):
        party_size[i, k] = random.randint(2, max_party_size)
        
print(f"{max_party_size}\n")
print(f"{party_size}")
# Out:
# 8
#
# {(0, 0): 3, (1, 0): 4, (2, 0): 5, (3, 0): 3, (4, 0): 5, (5, 0): 2, (6, 0): 7, (7, 0): 4, (8, 0): 7, (9, 0): 2, (10, 0): 4, (0, 1): 5, (1, 1): 4, (2, 1): 6, (3, 1): 2, (4, 1): 3, (5, 1): 3, (6, 1): 2, (7, 1): 4, (8, 1): 3, (9, 1): 6, (10, 1): 2, (11, 1): 7, (12, 1): 4, (13, 1): 3, (14, 1): 5, (15, 1): 6, (16, 1): 2, (17, 1): 6, (18, 1): 4, (19, 1): 2, (20, 1): 3, (21, 1): 3, (22, 1): 6, (23, 1): 6, (0, 2): 6, (1, 2): 5, (2, 2): 2, (3, 2): 7, (4, 2): 8, (5, 2): 6, (6, 2): 8, (7, 2): 5, (8, 2): 7, (9, 2): 6, (10, 2): 3, (11, 2): 4, (12, 2): 3, (13, 2): 4, (14, 2): 4, (15, 2): 4, (16, 2): 8, (17, 2): 5, (18, 2): 4, (19, 2): 3, (20, 2): 5, (21, 2): 5, (22, 2): 8, (0, 3): 3, (1, 3): 2, (2, 3): 5, (3, 3): 2, (4, 3): 5, (5, 3): 4, (6, 3): 7, (7, 3): 2, (8, 3): 5, (9, 3): 4, (10, 3): 4, (11, 3): 2, (0, 4): 6, (1, 4): 5, (2, 4): 8, (3, 4): 2, (4, 4): 7, (5, 4): 5, (6, 4): 5, (7, 4): 7, (8, 4): 2, (9, 4): 8, (10, 4): 7, (11, 4): 5, (12, 4): 6, (13, 4): 8, (14, 4): 2, (15, 4): 3, (16, 4): 7, (17, 4): 6, (18, 4): 8, (19, 4): 7, (20, 4): 3, (21, 4): 3, (22, 4): 5, (23, 4): 3, (24, 4): 3, (25, 4): 6, (26, 4): 3, (27, 4): 2, (28, 4): 3, (29, 4): 3, (30, 4): 2, (31, 4): 6, (32, 4): 4, (33, 4): 5, (34, 4): 8, (35, 4): 7, (36, 4): 7, (37, 4): 7, (0, 5): 5, (1, 5): 2, (2, 5): 2, (3, 5): 8, (4, 5): 6, (5, 5): 3, (6, 5): 5, (7, 5): 4, (8, 5): 2, (9, 5): 7, (10, 5): 8, (11, 5): 8, (12, 5): 6, (13, 5): 5, (14, 5): 7, (15, 5): 4, (16, 5): 6, (17, 5): 2, (18, 5): 4, (19, 5): 3, (20, 5): 3, (21, 5): 7, (22, 5): 3, (23, 5): 2, (24, 5): 5, (25, 5): 8, (26, 5): 6, (27, 5): 4, (28, 5): 8, (29, 5): 4, (30, 5): 7, (0, 6): 4, (1, 6): 8, (2, 6): 7, (3, 6): 2, (4, 6): 6, (5, 6): 7, (6, 6): 8, (7, 6): 8, (8, 6): 2, (9, 6): 2}

# %% [markdown]
# ### Step 3: Calculate table sizes and space that each party will occupy if seated

# %%
# the table mapping below represents
# how many tables a specific party_size would require
table_mapping = {}
for i in range(2,max_party_size + 1):
    table_mapping[i] = i // 2 + i % 2

# initializing the amount of space that each of the party sizes 
# would take up
space = {}
for k in range(K):
    for i in range(I[k]):
        num_tables = table_mapping.get(party_size[i, k])
        space[i, k] = 6 + 3 * num_tables

# %% [markdown]
# ### Step 4: Create and pre-populate data structures

# %%
sorted_space = space.copy()

sorted_space = {k: v for k, v in sorted(sorted_space.items(), key=lambda item: item[1], reverse=True)}
sorted_space = {k: v for k, v in sorted(sorted_space.items(), key=lambda item: item[0][1], reverse=False)}
print(f"{sorted_space}")
# Out:
# {(6, 0): 18, (8, 0): 18, (2, 0): 15, (4, 0): 15, (0, 0): 12, (1, 0): 12, (3, 0): 12, (7, 0): 12, (10, 0): 12, (5, 0): 9, (9, 0): 9, (11, 1): 18, (0, 1): 15, (2, 1): 15, (9, 1): 15, (14, 1): 15, (15, 1): 15, (17, 1): 15, (22, 1): 15, (23, 1): 15, (1, 1): 12, (4, 1): 12, (5, 1): 12, (7, 1): 12, (8, 1): 12, (12, 1): 12, (13, 1): 12, (18, 1): 12, (20, 1): 12, (21, 1): 12, (3, 1): 9, (6, 1): 9, (10, 1): 9, (16, 1): 9, (19, 1): 9, (3, 2): 18, (4, 2): 18, (6, 2): 18, (8, 2): 18, (16, 2): 18, (22, 2): 18, (0, 2): 15, (1, 2): 15, (5, 2): 15, (7, 2): 15, (9, 2): 15, (17, 2): 15, (20, 2): 15, (21, 2): 15, (10, 2): 12, (11, 2): 12, (12, 2): 12, (13, 2): 12, (14, 2): 12, (15, 2): 12, (18, 2): 12, (19, 2): 12, (2, 2): 9, (6, 3): 18, (2, 3): 15, (4, 3): 15, (8, 3): 15, (0, 3): 12, (5, 3): 12, (9, 3): 12, (10, 3): 12, (1, 3): 9, (3, 3): 9, (7, 3): 9, (11, 3): 9, (2, 4): 18, (4, 4): 18, (7, 4): 18, (9, 4): 18, (10, 4): 18, (13, 4): 18, (16, 4): 18, (18, 4): 18, (19, 4): 18, (34, 4): 18, (35, 4): 18, (36, 4): 18, (37, 4): 18, (0, 4): 15, (1, 4): 15, (5, 4): 15, (6, 4): 15, (11, 4): 15, (12, 4): 15, (17, 4): 15, (22, 4): 15, (25, 4): 15, (31, 4): 15, (33, 4): 15, (15, 4): 12, (20, 4): 12, (21, 4): 12, (23, 4): 12, (24, 4): 12, (26, 4): 12, (28, 4): 12, (29, 4): 12, (32, 4): 12, (3, 4): 9, (8, 4): 9, (14, 4): 9, (27, 4): 9, (30, 4): 9, (3, 5): 18, (9, 5): 18, (10, 5): 18, (11, 5): 18, (14, 5): 18, (21, 5): 18, (25, 5): 18, (28, 5): 18, (30, 5): 18, (0, 5): 15, (4, 5): 15, (6, 5): 15, (12, 5): 15, (13, 5): 15, (16, 5): 15, (24, 5): 15, (26, 5): 15, (5, 5): 12, (7, 5): 12, (15, 5): 12, (18, 5): 12, (19, 5): 12, (20, 5): 12, (22, 5): 12, (27, 5): 12, (29, 5): 12, (1, 5): 9, (2, 5): 9, (8, 5): 9, (17, 5): 9, (23, 5): 9, (1, 6): 18, (2, 6): 18, (5, 6): 18, (6, 6): 18, (7, 6): 18, (4, 6): 15, (0, 6): 12, (3, 6): 9, (8, 6): 9, (9, 6): 9}

# %%
# initializing a list of keys for the space dictionary
keys_list = list(sorted_space)


# looping over each of the time slot's sorted party sizes 
timeslot_sorted_parties = {}
global_counter = 0
for k in range(K):
    counter = 0
    sorted_parties=[]
    for key in sorted_space.keys():
        sorted_parties.append(sorted_space[keys_list[global_counter]])
        counter += 1
        global_counter += 1
        if(counter == I[k]):
            break
    timeslot_sorted_parties[k] = sorted_parties
print(f"{timeslot_sorted_parties}")
#print(f"{sorted_space}")
#print(f"{sorted_space[sorted_space[i],i]}")

x = [[0 for i in range(I[k])] for k in range(K)]
# Out:
# {0: [18, 18, 15, 15, 12, 12, 12, 12, 12, 9, 9], 1: [18, 15, 15, 15, 15, 15, 15, 15, 15, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 9, 9, 9, 9, 9], 2: [18, 18, 18, 18, 18, 18, 15, 15, 15, 15, 15, 15, 15, 15, 12, 12, 12, 12, 12, 12, 12, 12, 9], 3: [18, 15, 15, 15, 12, 12, 12, 12, 9, 9, 9, 9], 4: [18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 12, 12, 12, 12, 12, 12, 12, 12, 12, 9, 9, 9, 9, 9], 5: [18, 18, 18, 18, 18, 18, 18, 18, 18, 15, 15, 15, 15, 15, 15, 15, 15, 12, 12, 12, 12, 12, 12, 12, 12, 12, 9, 9, 9, 9, 9], 6: [18, 18, 18, 18, 18, 15, 12, 9, 9, 9]}

# %% [markdown]
# ### Step 5: Construction Heuristic

# %%
# Observation: Sometimes we have a party size of 3/5 instead of 4/6 get allocated even though 4 will produce more revenue.
# This is because the space occupied by each is the same.
# Way we can do this is by sorting at party_size instead of space and that will propogate.
binaries = []
daily_revenue = 0
counter = 0
for k in range(K):
    revenue = 0
    occupied_space = 0
    print(f"timeslot{k}")
    for i in range(I[k]):
        #dict_to_append = {}
        #dict_to_append[i,k] = [0, 0]
        size_of_party =party_size[keys_list[counter]]
        if (occupied_space + timeslot_sorted_parties[k][i] < MAX_SIZE):
            occupied_space += timeslot_sorted_parties[k][i]
            x[k][i] = 1
            added_revenue = marginal_revenue[size_of_party] * size_of_party
            revenue += added_revenue
            #dict_to_append[i,k] = [1, added_revenue]
            binaries.append([i,size_of_party,k,1,added_revenue,revenue])

            print(f"party size = {size_of_party}, marginal revenue = {marginal_revenue[size_of_party]}, rev={revenue}")
        else:
            binaries.append([i,size_of_party,k,'',0,revenue])
        counter+=1
    print(f"{occupied_space}\n")
# Out:
# timeslot0
# party size = 7, marginal revenue = 29, rev=203
# party size = 7, marginal revenue = 29, rev=406
# party size = 5, marginal revenue = 24, rev=526
# party size = 5, marginal revenue = 24, rev=646
# party size = 3, marginal revenue = 23, rev=715
# party size = 4, marginal revenue = 22, rev=803
# party size = 3, marginal revenue = 23, rev=872
# party size = 4, marginal revenue = 22, rev=960
# party size = 4, marginal revenue = 22, rev=1048
# party size = 2, marginal revenue = 26, rev=1100
# party size = 2, marginal revenue = 26, rev=1152
# 144
#
# timeslot1
# party size = 7, marginal revenue = 29, rev=203
# party size = 5, marginal revenue = 24, rev=323
# party size = 6, marginal revenue = 28, rev=491
# party size = 6, marginal revenue = 28, rev=659
# party size = 5, marginal revenue = 24, rev=779
# party size = 6, marginal revenue = 28, rev=947
# party size = 6, marginal revenue = 28, rev=1115
# party size = 6, marginal revenue = 28, rev=1283
# party size = 6, marginal revenue = 28, rev=1451
# party size = 4, marginal revenue = 22, rev=1539
# party size = 3, marginal revenue = 23, rev=1608
# party size = 3, marginal revenue = 23, rev=1677
# party size = 4, marginal revenue = 22, rev=1765
# party size = 3, marginal revenue = 23, rev=1834
# party size = 4, marginal revenue = 22, rev=1922
# party size = 3, marginal revenue = 23, rev=1991
# 222
#
# timeslot2
# party size = 7, marginal revenue = 29, rev=203
# party size = 8, marginal revenue = 30, rev=443
# party size = 8, marginal revenue = 30, rev=683
# party size = 7, marginal revenue = 29, rev=886
# party size = 8, marginal revenue = 30, rev=1126
# party size = 8, marginal revenue = 30, rev=1366
# party size = 6, marginal revenue = 28, rev=1534
# party size = 5, marginal revenue = 24, rev=1654
# party size = 6, marginal revenue = 28, rev=1822
# party size = 5, marginal revenue = 24, rev=1942
# party size = 6, marginal revenue = 28, rev=2110
# party size = 5, marginal revenue = 24, rev=2230
# party size = 5, marginal revenue = 24, rev=2350
# party size = 2, marginal revenue = 26, rev=2402
# 222
#
# timeslot3
# party size = 7, marginal revenue = 29, rev=203
# party size = 5, marginal revenue = 24, rev=323
# party size = 5, marginal revenue = 24, rev=443
# party size = 5, marginal revenue = 24, rev=563
# party size = 3, marginal revenue = 23, rev=632
# party size = 4, marginal revenue = 22, rev=720
# party size = 4, marginal revenue = 22, rev=808
# party size = 4, marginal revenue = 22, rev=896
# party size = 2, marginal revenue = 26, rev=948
# party size = 2, marginal revenue = 26, rev=1000
# party size = 2, marginal revenue = 26, rev=1052
# party size = 2, marginal revenue = 26, rev=1104
# 147
#
# timeslot4
# party size = 8, marginal revenue = 30, rev=240
# party size = 7, marginal revenue = 29, rev=443
# party size = 7, marginal revenue = 29, rev=646
# party size = 8, marginal revenue = 30, rev=886
# party size = 7, marginal revenue = 29, rev=1089
# party size = 8, marginal revenue = 30, rev=1329
# party size = 7, marginal revenue = 29, rev=1532
# party size = 8, marginal revenue = 30, rev=1772
# party size = 7, marginal revenue = 29, rev=1975
# party size = 8, marginal revenue = 30, rev=2215
# party size = 7, marginal revenue = 29, rev=2418
# party size = 7, marginal revenue = 29, rev=2621
# 216
#
# timeslot5
# party size = 8, marginal revenue = 30, rev=240
# party size = 7, marginal revenue = 29, rev=443
# party size = 8, marginal revenue = 30, rev=683
# party size = 8, marginal revenue = 30, rev=923
# party size = 7, marginal revenue = 29, rev=1126
# party size = 7, marginal revenue = 29, rev=1329
# party size = 8, marginal revenue = 30, rev=1569
# party size = 8, marginal revenue = 30, rev=1809
# party size = 7, marginal revenue = 29, rev=2012
# party size = 5, marginal revenue = 24, rev=2132
# party size = 6, marginal revenue = 28, rev=2300
# party size = 5, marginal revenue = 24, rev=2420
# party size = 6, marginal revenue = 28, rev=2588
# 222
#
# timeslot6
# party size = 8, marginal revenue = 30, rev=240
# party size = 7, marginal revenue = 29, rev=443
# party size = 7, marginal revenue = 29, rev=646
# party size = 8, marginal revenue = 30, rev=886
# party size = 8, marginal revenue = 30, rev=1126
# party size = 6, marginal revenue = 28, rev=1294
# party size = 4, marginal revenue = 22, rev=1382
# party size = 2, marginal revenue = 26, rev=1434
# party size = 2, marginal revenue = 26, rev=1486
# party size = 2, marginal revenue = 26, rev=1538
# 144

# %% [markdown]
# ### Step 6: Simulated Annealing

# %%
for i in binaries:
    print(f"{i}")

#for key in sorted_space.keys():
    #print(f"{key}")
 #   print(f"{x[key[0]][key[1]]}")
# Out:
# [0, 7, 0, 1, 203, 203]
# [1, 7, 0, 1, 203, 406]
# [2, 5, 0, 1, 120, 526]
# [3, 5, 0, 1, 120, 646]
# [4, 3, 0, 1, 69, 715]
# [5, 4, 0, 1, 88, 803]
# [6, 3, 0, 1, 69, 872]
# [7, 4, 0, 1, 88, 960]
# [8, 4, 0, 1, 88, 1048]
# [9, 2, 0, 1, 52, 1100]
# [10, 2, 0, 1, 52, 1152]
# [0, 7, 1, 1, 203, 203]
# [1, 5, 1, 1, 120, 323]
# [2, 6, 1, 1, 168, 491]
# [3, 6, 1, 1, 168, 659]
# [4, 5, 1, 1, 120, 779]
# [5, 6, 1, 1, 168, 947]
# [6, 6, 1, 1, 168, 1115]
# [7, 6, 1, 1, 168, 1283]
# [8, 6, 1, 1, 168, 1451]
# [9, 4, 1, 1, 88, 1539]
# [10, 3, 1, 1, 69, 1608]
# [11, 3, 1, 1, 69, 1677]
# [12, 4, 1, 1, 88, 1765]
# [13, 3, 1, 1, 69, 1834]
# [14, 4, 1, 1, 88, 1922]
# [15, 3, 1, 1, 69, 1991]
# [16, 4, 1, '', 0, 1991]
# [17, 3, 1, '', 0, 1991]
# [18, 3, 1, '', 0, 1991]
# [19, 2, 1, '', 0, 1991]
# [20, 2, 1, '', 0, 1991]
# [21, 2, 1, '', 0, 1991]
# [22, 2, 1, '', 0, 1991]
# [23, 2, 1, '', 0, 1991]
# [0, 7, 2, 1, 203, 203]
# [1, 8, 2, 1, 240, 443]
# [2, 8, 2, 1, 240, 683]
# [3, 7, 2, 1, 203, 886]
# [4, 8, 2, 1, 240, 1126]
# [5, 8, 2, 1, 240, 1366]
# [6, 6, 2, 1, 168, 1534]
# [7, 5, 2, 1, 120, 1654]
# [8, 6, 2, 1, 168, 1822]
# [9, 5, 2, 1, 120, 1942]
# [10, 6, 2, 1, 168, 2110]
# [11, 5, 2, 1, 120, 2230]
# [12, 5, 2, 1, 120, 2350]
# [13, 5, 2, '', 0, 2350]
# [14, 3, 2, '', 0, 2350]
# [15, 4, 2, '', 0, 2350]
# [16, 3, 2, '', 0, 2350]
# [17, 4, 2, '', 0, 2350]
# [18, 4, 2, '', 0, 2350]
# [19, 4, 2, '', 0, 2350]
# [20, 4, 2, '', 0, 2350]
# [21, 3, 2, '', 0, 2350]
# [22, 2, 2, 1, 52, 2402]
# [0, 7, 3, 1, 203, 203]
# [1, 5, 3, 1, 120, 323]
# [2, 5, 3, 1, 120, 443]
# [3, 5, 3, 1, 120, 563]
# [4, 3, 3, 1, 69, 632]
# [5, 4, 3, 1, 88, 720]
# [6, 4, 3, 1, 88, 808]
# [7, 4, 3, 1, 88, 896]
# [8, 2, 3, 1, 52, 948]
# [9, 2, 3, 1, 52, 1000]
# [10, 2, 3, 1, 52, 1052]
# [11, 2, 3, 1, 52, 1104]
# [0, 8, 4, 1, 240, 240]
# [1, 7, 4, 1, 203, 443]
# [2, 7, 4, 1, 203, 646]
# [3, 8, 4, 1, 240, 886]
# [4, 7, 4, 1, 203, 1089]
# [5, 8, 4, 1, 240, 1329]
# [6, 7, 4, 1, 203, 1532]
# [7, 8, 4, 1, 240, 1772]
# [8, 7, 4, 1, 203, 1975]
# [9, 8, 4, 1, 240, 2215]
# [10, 7, 4, 1, 203, 2418]
# [11, 7, 4, 1, 203, 2621]
# [12, 7, 4, '', 0, 2621]
# [13, 6, 4, '', 0, 2621]
# [14, 5, 4, '', 0, 2621]
# [15, 5, 4, '', 0, 2621]
# [16, 5, 4, '', 0, 2621]
# [17, 5, 4, '', 0, 2621]
# [18, 6, 4, '', 0, 2621]
# [19, 6, 4, '', 0, 2621]
# [20, 5, 4, '', 0, 2621]
# [21, 6, 4, '', 0, 2621]
# [22, 6, 4, '', 0, 2621]
# [23, 5, 4, '', 0, 2621]
# [24, 3, 4, '', 0, 2621]
# [25, 3, 4, '', 0, 2621]
# [26, 3, 4, '', 0, 2621]
# [27, 3, 4, '', 0, 2621]
# [28, 3, 4, '', 0, 2621]
# [29, 3, 4, '', 0, 2621]
# [30, 3, 4, '', 0, 2621]
# [31, 3, 4, '', 0, 2621]
# [32, 4, 4, '', 0, 2621]
# [33, 2, 4, '', 0, 2621]
# [34, 2, 4, '', 0, 2621]
# [35, 2, 4, '', 0, 2621]
# [36, 2, 4, '', 0, 2621]
# [37, 2, 4, '', 0, 2621]
# [0, 8, 5, 1, 240, 240]
# [1, 7, 5, 1, 203, 443]
# [2, 8, 5, 1, 240, 683]
# [3, 8, 5, 1, 240, 923]
# [4, 7, 5, 1, 203, 1126]
# [5, 7, 5, 1, 203, 1329]
# [6, 8, 5, 1, 240, 1569]
# [7, 8, 5, 1, 240, 1809]
# [8, 7, 5, 1, 203, 2012]
# [9, 5, 5, 1, 120, 2132]
# [10, 6, 5, 1, 168, 2300]
# [11, 5, 5, 1, 120, 2420]
# [12, 6, 5, 1, 168, 2588]
# [13, 5, 5, '', 0, 2588]
# [14, 6, 5, '', 0, 2588]
# [15, 5, 5, '', 0, 2588]
# [16, 6, 5, '', 0, 2588]
# [17, 3, 5, '', 0, 2588]
# [18, 4, 5, '', 0, 2588]
# [19, 4, 5, '', 0, 2588]
# [20, 4, 5, '', 0, 2588]
# [21, 3, 5, '', 0, 2588]
# [22, 3, 5, '', 0, 2588]
# [23, 3, 5, '', 0, 2588]
# [24, 4, 5, '', 0, 2588]
# [25, 4, 5, '', 0, 2588]
# [26, 2, 5, '', 0, 2588]
# [27, 2, 5, '', 0, 2588]
# [28, 2, 5, '', 0, 2588]
# [29, 2, 5, '', 0, 2588]
# [30, 2, 5, '', 0, 2588]
# [0, 8, 6, 1, 240, 240]
# [1, 7, 6, 1, 203, 443]
# [2, 7, 6, 1, 203, 646]
# [3, 8, 6, 1, 240, 886]
# [4, 8, 6, 1, 240, 1126]
# [5, 6, 6, 1, 168, 1294]
# [6, 4, 6, 1, 88, 1382]
# [7, 2, 6, 1, 52, 1434]
# [8, 2, 6, 1, 52, 1486]
# [9, 2, 6, 1, 52, 1538]

# %%
import csv

with open('dict.csv', 'w') as csv_file:  
    writer = csv.writer(csv_file)
    writer.writerow(["Party i", "Size""Timeslot k", "seated (binary)", "added revenue"])
    for i in binaries:
       writer.writerow(i)
