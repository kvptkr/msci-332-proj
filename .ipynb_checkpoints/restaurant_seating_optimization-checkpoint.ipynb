# %% [markdown]
# ## Restaurant Seat Optimization
#
#
#
#
# #### Step 1: Import gurobipy module

# %%
import gurobipy as gp
from gurobipy import GRB
import random

# %% [markdown]
# #### Step 2: Define your model

# %%
m = gp.Model()
# Out:
# Using license file /Users/matthewfollegot/gurobi.lic
# Academic license - for non-commercial use only

# %% [markdown]
# #### Step 3: Define your sets

# %%
#number of parties at a timeslot
I = 40

#number of timeslots
K = 7

# %% [markdown]
# #### Step 4: Define your parameters

# %%
#TODO: align on numbers for this, good candidate for sensitivity
# width and length of the dining room, in m
w = 20
l = 20


#initializing the party 
party_size = {}
for i in range(I):
    for k in range(K):
        party_size[i, k] = random.randint(2,6)
        #print(party_size[i,k])

# the table mapping below represents
# how many tables a specific party_size would require
table_mapping = { 
    2: 1,
    3: 2,
    4: 2,
    5: 3,
    6: 3
}

# initializing the amount of space that each of the party sizes 
# would take up
space = {}
for i in range(I):
    for k in range(K):
        num_tables = table_mapping.get(party_size[i, k])
        space[i, k] = 6 + 3 * num_tables

# %% [markdown]
# #### Step 5: Define your decision variables

# %%
# defining xik, whethere or not party i is seated at timeslot k
x = {}
for i in range(I):
    for k in range(K):
        x[i,k] = m.addVar(lb=0.0, obj=23.04*party_size[i,k], vtype=GRB.BINARY, name="x_"+str(i)+str(k))
        
#defining bk, whether or not there is a social distancing violation at timeslot k
b={}
for k in range(K):
    b[k] = m.addVar(lb=0.0, obj=-880, vtype=GRB.BINARY, name="b_"+str(k))
    
# defining the piecewise function for revenue
# model.setPWLObj()
s = {}
#defining space slack variable
for k in range(K):
    s[k] = m.addVar(lb=0.0, vtype=GRB.INTEGER, name="s_"+str(k))

#defining space excess variable
e = {}
for k in range(K):
    e[k] = m.addVar(lb=0.0, vtype=GRB.INTEGER, name="e_" + str(k))

# #defining C
# m.addVar(obj=-25000, vtype=GRB.BINARY, name="C")

# %% [markdown]
# #### Step 6: Set your objective function

# %%
m.modelSense = GRB.MAXIMIZE

# %% [markdown]
# #### Step 7: Add Constraints

# %%
# defining space constraint
for k in range(K):
    running_sum = 0
    for i in range(I):
        #print(running_sum)
        #xik = m.getVarByName("x_"+str(i) + str(k)).X
        #print(xik)
#         spaceik = space[i,k]
        running_sum += x[i,k]*space[i,k]
#    print(running_sum)
    m.addConstr((s[k] - e[k] + running_sum), GRB.EQUAL, l*w)

print(f"l={l}, w={w}")
    
# defining the constraint that turns on the social distancing violated binary var
for k in range(K):
    m.addConstr(10**6*b[k], GRB.GREATER_EQUAL, e[k])

# defining the constraint that makes sure that if there are social distancing violations,
# they take up at most 20% of the dining room
for k in range(K):
    m.addConstr(e[k], GRB.LESS_EQUAL, l * w * 0.2)
    
# defining the constraint that makes sure that each party only occupies one table
for k in range(K):
    for i in range(I):
        m.addConstr(x[i,k], GRB.LESS_EQUAL, 1)

# for k in range(K):
#     m.addConstr(s[k], GRB.LESS_EQUAL, l*w*0.2)
    
m.update()
# Out:
# l=20, w=20

# %% [markdown]
# #### Step 8: Solve the model

# %%
m.optimize()
# Out:
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (mac64)
# Optimize a model with 301 rows, 301 columns and 595 nonzeros
# Model fingerprint: 0x1295adcb
# Variable types: 0 continuous, 301 integer (287 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [5e+01, 9e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Found heuristic solution: objective -0.0000000
# Presolve removed 300 rows and 295 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 6 columns, 6 nonzeros
# Found heuristic solution: objective 21634.560000
# Variable types: 0 continuous, 6 integer (1 binary)
#
# Root relaxation: objective 2.181312e+04, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 21813.1200    0    1 21634.5600 21813.1200  0.83%     -    0s
# H    0     0                    21795.840000 21813.1200  0.08%     -    0s
#      0     0 21813.1200    0    1 21795.8400 21813.1200  0.08%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.07 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 21795.8 21634.6 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.179584000000e+04, best bound 2.179584000000e+04, gap 0.0000%

# %% [markdown]
# #### Step 8: Print variable values  (The Messy Way)

# %%
print("Printing result\n")
print('\nProfit: %g' % m.objVal) #gets the objective function value
print('\nSOLUTION')
for myVars in m.getVars():
    #print(myVars)
    print('%s %g' % (myVars.varName, myVars.x))
# Out:
# Printing result
#
#
# Profit: 21795.8
#
# SOLUTION
# x_00 1
# x_01 0
# x_02 1
# x_03 0
# x_04 0
# x_05 1
# x_06 0
# x_10 1
# x_11 1
# x_12 1
# x_13 1
# x_14 0
# x_15 0
# x_16 1
# x_20 1
# x_21 1
# x_22 0
# x_23 1
# x_24 1
# x_25 1
# x_26 1
# x_30 0
# x_31 1
# x_32 1
# x_33 1
# x_34 1
# x_35 1
# x_36 1
# x_40 1
# x_41 1
# x_42 1
# x_43 1
# x_44 0
# x_45 0
# x_46 1
# x_50 1
# x_51 1
# x_52 0
# x_53 1
# x_54 1
# x_55 1
# x_56 1
# x_60 1
# x_61 1
# x_62 1
# x_63 1
# x_64 0
# x_65 1
# x_66 1
# x_70 0
# x_71 1
# x_72 1
# x_73 1
# x_74 1
# x_75 0
# x_76 1
# x_80 0
# x_81 1
# x_82 1
# x_83 1
# x_84 0
# x_85 0
# x_86 1
# x_90 1
# x_91 1
# x_92 0
# x_93 1
# x_94 1
# x_95 1
# x_96 1
# x_100 0
# x_101 0
# x_102 1
# x_103 1
# x_104 1
# x_105 1
# x_106 -0
# x_110 1
# x_111 0
# x_112 0
# x_113 0
# x_114 1
# x_115 1
# x_116 1
# x_120 1
# x_121 1
# x_122 0
# x_123 1
# x_124 1
# x_125 1
# x_126 0
# x_130 1
# x_131 1
# x_132 1
# x_133 1
# x_134 0
# x_135 1
# x_136 0
# x_140 1
# x_141 1
# x_142 1
# x_143 1
# x_144 1
# x_145 1
# x_146 1
# x_150 1
# x_151 1
# x_152 0
# x_153 1
